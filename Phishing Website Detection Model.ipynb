# %% [markdown]
# ##### Author
#
# **Name**: Andres Figueroa
# **Email**: andresfigueroa@brandeis.edu
#
# ##### Project Description
#
# This project aims to build a machine learning classifier that can detect whether a given website URL is phishing (malicious) or legitimate (safe). By extracting and analyzing features from raw URLs.
#
# ---

# %% [markdown]
# #### Importing Libraries

# %%
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import SMOTE
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import make_scorer, recall_score, classification_report, confusion_matrix, roc_auc_score, precision_recall_curve, auc, roc_curve,precision_score, recall_score, f1_score
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.metrics import ConfusionMatrixDisplay, RocCurveDisplay, PrecisionRecallDisplay
from sklearn.model_selection import cross_val_score, StratifiedKFold, GridSearchCV, RandomizedSearchCV, StratifiedKFold, train_test_split
from scipy.stats import randint, uniform
from collections import Counter

# %% [markdown]
# ---
#
# ### Step 1: Loading and Exploring the Dataset

# %%
df = pd.read_csv('phishing_site_urls.csv')

print(df.columns)
print(df.head())
# Out:
# Index(['URL', 'Label'], dtype='object')
#                                                  URL Label
# 0  nobell.it/70ffb52d079109dca5664cce6f317373782/...   bad
# 1  www.dghjdgf.com/paypal.co.uk/cycgi-bin/webscrc...   bad
# 2  serviciosbys.com/paypal.cgi.bin.get-into.herf....   bad
# 3  mail.printakid.com/www.online.americanexpress....   bad
# 4  thewhiskeydregs.com/wp-content/themes/widescre...   bad

# %% [markdown]
# ---
#
# ### Step 2: Defining Our ML Problem
#
# ##### Dataset Explanation
#
# The dataset consists of raw website URLs along with labels indicating whether each URL is **phishing (bad)** or **legitimate (good)**. From these raw strings, we extract key features that represent characteristics often associated with phishing websites.
#
# The dataset includes:
#
# - Raw URL strings
# - Labels (`good` or `bad`)
#
# ---
#
# ##### 🎯 Prediction Target (Label)
#
# The label we are predicting is: `Label`
#
# This is a binary classification target:
#
# - `1` → The URL is 'bad' **(malicious)**
# - `0` → The URL is 'good' **(safe)**
#
# ---
#
# ##### Problem Type
#
# This is a supervised learning problem because we are training the model using examples with known outcomes (i.e., labeled URLs).
#
# - **Type**: Binary Classification
# - **Goal**: Predict whether a given website URL is phishing or not
#
# ---
#
# ##### Importance
#
# Phishing attacks are one of the most common cybersecurity threats, used to steal personal data, login credentials, or financial information. This project is important because:
#
# - It shows how machine learning can aid in automated phishing detection
# - It highlights the power of feature engineering for security-related tasks
# - It has practical use cases in browser security, email filtering, and endpoint protection tools
#
# ---

# %% [markdown]
# ### Step 3: Understanding Our Data

# %% [markdown]
# #### Missing Values

# %%
df.isnull().sum()
# Out:
# URL      0
# Label    0
# dtype: int64

# %% [markdown]
# > **Note:** No missing values, great!

# %%
df.dtypes
# Out:
# URL      object
# Label    object
# dtype: object

# %% [markdown]
# > **Note:** The `Label` column contains string values, so we need to convert it into a binary format for the model:
# > - **bad** → `1` (phishing)
# > - **good** → `0` (legitimate)

# %%
df['Label'].value_counts()
# Out:
# Label
# good    392924
# bad     156422
# Name: count, dtype: int64

# %% [markdown]
# > **Note:** There is a good amount of data, but there is also an imbalance between the two classifications.

# %% [markdown]
# #### Features to Engineer
# - `url_length`: Number of characters in the URL
# - `num_dots`: Number of `.` characters
# - `has_https`: `1` if the URL contains `'https'`, else `0`
# - `has_at`: `1` if the URL contains `'@'`, else `0`
# - `num_hyphens`: Number of `-` characters
# - `num_slashes`: Number of `/` characters
# - `has_ip_address`: `1` if the URL includes an IP address (e.g., `192.168.1.1`), else `0`
#
# > These patterns are commonly found in phishing URLs. Attackers use tricks like including IP addresses instead of domain names, adding many subdomains, or inserting symbols like @ to confuse users and hide the real destination of the link. These features help the model recognize suspicious URL structures.

# %% [markdown]
# #### URL `Length`

# %%
def get_url_length(url):
    return len(url)

df['url_length'] = df['URL'].apply(get_url_length)

# %% [markdown]
# > **Note:** Creates a column with the number of characters in a URL

# %% [markdown]
# #### Number of Dots `.`

# %%
def count_dots(url):
    return url.count('.')

df['num_dots'] = df['URL'].apply(count_dots)

# %% [markdown]
# > **Note:** Creates a column that determines the number of `.` characters in a URL

# %% [markdown]
# #### Whether a URL has `HTTPS` or Not

# %%
def check_https(url):
    return 1 if 'https' in url.lower() else 0

df['has_https'] = df['URL'].apply(check_https)

# %% [markdown]
# > **Note:** This feature creates a column that checks whether a URL uses HTTPS.
# > - `1` → URL **contains** `'https'` (secure)
# > - `0` → URL **does not contain** `'https'` (not secure)

# %% [markdown]
# #### Whether a URL has `@` or Not

# %%
def check_at_symbol(url):
    return 1 if '@' in url else 0

df['has_at'] = df['URL'].apply(check_at_symbol)

# %% [markdown]
# > **Note:** This feature creates a column that checks whether a URL uses @.
# > - `1` → URL **contains** `'@'`
# > - `0` → URL **does not contain** `'@'`

# %% [markdown]
# #### Number of Hyphens `-`

# %%
def count_hyphens(url):
    return url.count('-')

df['num_hyphens'] = df['URL'].apply(count_hyphens)

# %% [markdown]
# > **Note:** Creates a column that determines the number of `-` characters in a URL

# %% [markdown]
# #### Number of Slashes `/`

# %%
def count_slashes(url):
    return url.count('/')

df['num_slashes'] = df['URL'].apply(count_slashes)

# %% [markdown]
# > **Note:** Creates a column that determines the number of `/` characters in a URL

# %% [markdown]
# #### Whether a URL has an `IP Address` or Not

# %%
ip_pattern = r'\b(?:\d{1,3}\.){3}\d{1,3}\b'

def check_ip_address(url):
    return 1 if re.search(ip_pattern, url) else 0

df['has_ip_address'] = df['URL'].apply(check_ip_address)

# %% [markdown]
# > **Note:** This feature creates a column that checks whether a URL uses @.
# > - `1` → URL **contains** an IP Address
# > - `0` → URL **does not contain** an IP Address

# %% [markdown]
# #### Number of Suspicious Words

# %% [markdown]
# #### Encoding `'Label'` Our Label

# %%
df['Label'] = df['Label'].map({'good': 0, 'bad': 1})

# %% [markdown]
# #### Number of Suspicious Words

# %%
def get_words(url):
    return re.findall(r'[a-zA-Z0-9]+', url.lower())

phishing_urls = df[df['Label'] == 1]['URL']
legit_urls = df[df['Label'] == 0]['URL']

phish_words = Counter()
for url in phishing_urls:
    for word in get_words(url):
        phish_words[word] += 1

legit_words = Counter()
for url in legit_urls:
    for word in get_words(url):
        legit_words[word] += 1

suspicious_words = set()
for word, count in phish_words.items():
    if count > 20 and count > 3 * legit_words[word]:
        suspicious_words.add(word)

def suspicious_count(url):
    count = 0
    for word in get_words(url):
        if word in suspicious_words:
            count += 1
    return count

df['suspicious_word_count'] = df['URL'].apply(suspicious_count)
print(suspicious_words)
# Out:
# {'878hf33f34f', '26upsid', 'kk', 'loungio', 'banners', 'tar', 'xyvrmzdus', 'nwww', 'ee8d0b7e678a25d88', 'whatsapp', 'newepic2016', 'directiondereboursement', 'rtime', 'intads', 'fisc', '3foffertaid', 'beez5', 'id0498372885938paypal', 'tomsk', '143493053', 'safe', '96df1c84c7fb13e880e399f9627e0db0', 'kh', '4563', '20secure', 'ns2', '2fus', 'stedu', 'webappsecurity', 'userinfo', 'drive', '20roadstar', 'rogersandstephens', 'newdropbox', 'gravyseals', '54s5d48960qq14a2a1s0d5d8a12s0d5a8g6h0', 'highslide', '20global', 'nabatakoutdoors', 'jooble', 'accounte', '000000', 'kayabest', 'ambiente', '13inboxlightaspxn', 'gomelnaushnik', 'verifikationnets', '3dlt', '02tablet', 'mpolvora', 'webscrcmdaccountnav', 'ftempurl', 'n84', 'oxylala', 'travicoperu', 'v3', '4331', 'msy', 'kunden', '44031', 'xcvbn', 'myaccount', 'milkyway', 'realestateseller', 'keybase', '25e5', 'upl', 'offertaid', 'paypall', 'smartcards', 'usg', '8759j3f434', 'motorhomes', 'webscr1', 'colors', '108', 'xcqdlhtus', 'templates', 'httpdocs', 'stary', 'errortype', '159', 'krotzons', '238', '672bfcaa73dbfe28bff5bc77604084fa', 'asideal', 'skin', 'mage', 'pagename', 'es', 'cadastro3', 'grupodoma', '160624', 'duniaflowmeter', 'nolagroup', 'mgen', 'twentyten', 'leshrestaurant', 'cartasi', 'ethnophonie', 'sms', 'xn', 'yus', 'goo', '938fhnr3', '4dq', 'projecti', '255', 'x11s', 'intnet', 'mbi', 'newdocxb', 'sz', 'hid', 'newest', 'cloudaccess', 'p57vp8zln', '3fid', 'ysgrp', 'filemanager', 'imagens', 'amazonaws', 'einloggen', '194', 'bdfxb', 'scan', 'hopto', '26z', 'efax', '5885d80a13c0db1fb6947b0aeae66fd', 'nvellejaresearch', 'homa', 'websc', 'tam', 'hotclikz', '158', '64855', 'amzon', '171', 'icons', 'totalh', 'ntpd', 'webcsr', 'puserid', 'error', 'wlw', 'editors', 'poste', 'widgets', 'ias3', '20td', '253d', 'innovzen', 'dobb2', 'hxxp', 'certificates', 'kelownatownhomes', 'kr', 'bitly', 'verifiedbyvisa', 'gssss', 'ajempi', '6892', 'metacc', '0ahttp', 'trustpass', '188', 'libraries', 'tracking', 'altascdn', 'sss', 'sparkasse', 'mpmzmzmzut', 'cpiano', '114', '26cb', '5885d80a13c0db1f8e263663d3fa', '9ec6a36831afb00881f6b3809175870a', '127', 'verifed', 'login2', 'aspr', 'cliente', 'theteesbar', 'paulopr', 'avatars', 'living4u', 'joxk0idd', 'gy7f57f6', 'powerful', 'candidatura', 'utente', 'gz', 'confirmation', '229', 'oo', 'mediafe', 'data1', '20id', '6fa68d441c87e67e6814956e0128376f', '34136426436', 'c8aa27305bbb4ad7b769656766711e4b', '223', 'cmd', 'natwest', 'vaidevisa', 'rubiconproject', 'hapuka', 'dommel', '8976fyvgg', 'mail', 'tf', 'f5xraa2y2ybtrefz', 'herf', 'tela', 'zone1', 'yue', '217', 'computantest', 'informations', 'ugpvs', '91', '3designcenter', 'teste', '8080', 'lb', 'homezone', 'villakidsbuffetinfantil', 'classe', 'imbot', '2findex', 'iintx', 'buendigkeit', 'nnewsok', 'ringgatan', 'dispatchnhdjhudhds7766423456789ghf67gfhbn', 'install', '3d0', 'uv', 'gouv', '5352352353', 'add2cart', 'wz', 'efzg5epalogin', 'treasure', 'asb', '187', 'santander2016', '87yfhc', 'gripnet', 'cli', 'hmrc', 'ativar', 'f14de58cef', '173', 'nursegateway', '98h86f', '21rgz9pajrkosbemmlmqcyudckiaa', 'znvlbk2', 'logi2162662', 'ychoolgn12verifi2012c', 'admin', 'server93', 'asiandream', 'bbhmm', '8fh34f3', '83ab3de084d3d1666efac24e2fb59203', 'nwolb', 'suspendedpage', 'dpbx', 'voda', '4gbrdf6', '226', 'mhcable', 'tuif', 'idn', 'antica', 'putty', '53267548824646', 'comeinbaby', 'dz', 'azienda', 'payment', 'ib', 's7xide', 'users11', 'chave', 'apid', 'jscripts', 'yahoomail', 'frame', 'fancybox', '115', '167', 'ug7654fgy', 'username1', 'crm', '09uhv65hg', '09uk381', 'santruptiprojects', 'g38f3fg', 'helpers', 'zc3026', 'amz', '336264262473734', '221', 'attenzione', 'xyh', 'fid0', 'logon', 'exe', 'sabe', 'cn', 'siteid', 'db2', 'scama', '8g74crec', 'asd', 'verapdpf', 'really2', 'forestnice', 'tes', 'actualizacion', '910', 'inicio', 'loginsupin', 'rct', 'zz', 'luzetogodppw', 'creditcard', 'bankofamerica', '5885d80a13c0db1fb6947b0aeae66fdbfb2119927117e3a6f876e0fd34af436580c63a156ebffe89e7779ac84ebf634880c63a156ebffe ...

# %% [markdown]
# > **Note:** This identifies suspicious words and counts how many are in each URL. I previously didn't account for this feature. Seeing how our baseline (the logistic regression model) performed, I will continue to use and see how it affects the other models, the random forest and XGBoost.

# %%
df.head()
# Out:
#                                                  URL  Label  url_length  \
# 0  nobell.it/70ffb52d079109dca5664cce6f317373782/...      1         225
# 1  www.dghjdgf.com/paypal.co.uk/cycgi-bin/webscrc...      1          81
# 2  serviciosbys.com/paypal.cgi.bin.get-into.herf....      1         177
# 3  mail.printakid.com/www.online.americanexpress....      1          60
# 4  thewhiskeydregs.com/wp-content/themes/widescre...      1         116
#
#    num_dots  has_https  has_at  num_hyphens  num_slashes  has_ip_address  \
# 0         6          0       0            4           10               0
# 1         5          0       0            2            4               0
# 2         7          0       0            1           11               0
# 3         6          0       0            0            2               0
# 4         1          0       0            1           10               0
#
#    suspicious_word_count
# 0                     11
# 1                      7
# 2                     11
# 3                      1
# 4                      4

# %%
df.dtypes
# Out:
# URL                      object
# Label                     int64
# url_length                int64
# num_dots                  int64
# has_https                 int64
# has_at                    int64
# num_hyphens               int64
# num_slashes               int64
# has_ip_address            int64
# suspicious_word_count     int64
# dtype: object

# %% [markdown]
# #### Correlation Heatmap

# %%
df.drop(columns=['URL'], inplace=True)

corr = df.corr()
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# > **Note:** This is a correlation matrix heatmap. A heatmap shows how strongly each pair of features in our dataset is related. Correlation values range from:
# > - +1: perfect positive correlation (both variables increase together).
# > - 0: no linear relationship.
#
# > Here, our features have weak-to-moderate linear relationships with the target. So, there's not much linearity, so I probably don’t need to remove any features due to redundancy.

# %% [markdown]
# ---
# ### Step 4: Defining Our Project Plan
#
# #### Feature Selection
# After analyzing the data and the correlation matrix, I decided to **keep all existing engineered features**, as none showed excessive multicollinearity or redundancy. My final feature list is:
# - `url_length`
# - `num_dots`
# - `num_hyphens`
# - `num_slashes`
# - `has_https`
# - `has_at`
# - `has_ip_address`
#
# These features capture structural and security-related patterns in URLs that can help distinguish between phishing and legitimate sites.
#
# ---
#
# #### Data Preparation
# To prepare the data for modeling, I:
# 1. **Checked for and handled missing values**: I will validate before modeling.
# 2. **Encoding the Label**
# 3. **Address the Class Imbalance with SMOTE**
#
# ---
#
# #### Model Selection
# I plan to experiment with several models to find the best performer:
# - **Logistic Regression**: A strong baseline for binary classification.
# - **Random Forest Classifier**: A tree-based ensemble model that can handle non-linear relationships and provide feature importance.
# - **XGBoost Classifier**: A powerful gradient-boosted tree model that excels on tabular data.
#
# ---
#
# #### Evaluation Strategy
# To assess model performance:
#   - Precision
#   - Recall
#   - F1 Score
#   - ROC AUC Score
#
# Our main focus is going to be high recall for Class 1 (`phishing detection`)
#
# ---

# %% [markdown]
# ### Step 5: Implementing Our Project Plan

# %%
y = df['Label']
X = df.drop(columns = 'Label')

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 1234, stratify = y)

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled  = scaler.transform(X_test)

# %%
smote = SMOTE(random_state = 1234)
X_train_smote, y_train_smote = smote.fit_resample(X_train_scaled, y_train)

'''unique_smote, counts_smote = np.unique(y_train_smote, return_counts = True)
print("\nSMOTE class distribution:")
for label, count in zip(unique_smote, counts_smote):
    print(f"Label {label}: {count} samples")'''
# Out:
# 'unique_smote, counts_smote = np.unique(y_train_smote, return_counts = True)\nprint("\nSMOTE class distribution:")\nfor label, count in zip(unique_smote, counts_smote):\n    print(f"Label {label}: {count} samples")'

# %% [markdown]
# #### Training the Logistic Regression Model

# %%
lr = LogisticRegression(max_iter = 1000)
lr.fit(X_train_smote, y_train_smote)
y_pred = lr.predict(X_test_scaled)
y_proba = lr.predict_proba(X_test_scaled)[:, 1]

print(classification_report(y_test, y_pred))
print("ROC AUC:", roc_auc_score(y_test, y_proba))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.96      0.94    117877
#            1       0.89      0.79      0.84     46927
#
#     accuracy                           0.91    164804
#    macro avg       0.91      0.88      0.89    164804
# weighted avg       0.91      0.91      0.91    164804
#
# ROC AUC: 0.9385853439358373

# %% [markdown]
# > **Note:** The model seems to favor “good” URLs (as it has higher precision/recall), but struggles to identify “bad” (phishing) URLs, which is the priority in phishing detection.

# %% [markdown]
# #### Training the Random Forest Model

# %%
rf_model = RandomForestClassifier(random_state = 1234)
rf_model.fit(X_train_smote, y_train_smote)
y_pred = rf_model.predict(X_test_scaled)
y_proba = rf_model.predict_proba(X_test_scaled)[:, 1]

print(classification_report(y_test, y_pred))
print("ROC AUC:", roc_auc_score(y_test, y_proba))
# print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.96      0.94    117877
#            1       0.88      0.82      0.85     46927
#
#     accuracy                           0.92    164804
#    macro avg       0.90      0.89      0.90    164804
# weighted avg       0.92      0.92      0.92    164804
#
# ROC AUC: 0.9510779129694581

# %% [markdown]
# #### Hypertuning Parameters

# %%
param_dist = {
    'n_estimators': randint(50, 200),
    'max_depth': randint(3, 20),
    'min_samples_split': randint(2, 10),
    'min_samples_leaf': randint(1, 10),
    'max_features': ['sqrt', 'log2', None]
}

random_search = RandomizedSearchCV(
    estimator = RandomForestClassifier(random_state = 1234),
    param_distributions = param_dist,
    n_iter = 20,
    cv = 3,
    verbose = 1,
    n_jobs = -1,
    scoring = 'recall'
)

random_search.fit(X_train_smote, y_train_smote)
best_rf = random_search.best_estimator_
print("Best Parameters:", random_search.best_params_)
# Out:
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# Best Parameters: {'max_depth': 19, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 8, 'n_estimators': 135}

# %%
y_pred_rf = best_rf.predict(X_test_scaled)
y_proba_rf = best_rf.predict_proba(X_test_scaled)[:, 1]

print("Classification Report (Random Forest):")
print(classification_report(y_test, y_pred_rf))

roc_score = roc_auc_score(y_test, y_proba_rf)
print(f"ROC AUC Score: {roc_score}")
# Out:
# Classification Report (Random Forest):
#               precision    recall  f1-score   support
#
#            0       0.93      0.95      0.94    117877
#            1       0.88      0.82      0.85     46927
#
#     accuracy                           0.92    164804
#    macro avg       0.90      0.89      0.90    164804
# weighted avg       0.92      0.92      0.92    164804
#
# ROC AUC Score: 0.9527801941726924

# %% [markdown]
# #### Threshold Tuning

# %%
thresholds = np.arange(0.1, 0.9, 0.05)
precision_scores = []
recall_scores = []
f1_scores = []

for thresh in thresholds:
    y_pred_thresh = (y_proba_rf >= thresh).astype(int)
    precision_scores.append(precision_score(y_test, y_pred_thresh))
    recall_scores.append(recall_score(y_test, y_pred_thresh))
    f1_scores.append(f1_score(y_test, y_pred_thresh))

plt.figure(figsize=(10, 6))
plt.plot(thresholds, precision_scores, label = 'Precision', color = 'red')
plt.plot(thresholds, recall_scores, label = 'Recall', color = 'green')
plt.plot(thresholds, f1_scores, label = 'F1 Score', color = 'blue')
plt.axvline(x = 0.50, linestyle = '--', label = 'Threshold (0.50)')
plt.title("Precision, Recall, F1 vs Threshold")
plt.xlabel("Threshold")
plt.ylabel("Score")
plt.legend()
plt.grid(True)
plt.show()

# %%
best_idx = np.argmax(f1_scores)
best_threshold = thresholds[best_idx]
best_f1 = f1_scores[best_idx]

print(f"Optimal Threshold for Highest F1 Score: {best_threshold}")
print(f"Highest F1 Score: {best_f1}")
print(f"Precision: {precision_scores[best_idx]}, Recall: {recall_scores[best_idx]}")
# Out:
# Optimal Threshold for Highest F1 Score: 0.6000000000000002
# Highest F1 Score: 0.8575644574592208
# Precision: 0.9256698357821953, Recall: 0.7987938713320689

# %%
y_pred_best = (y_proba_rf >= best_threshold).astype(int)
print(classification_report(y_test, y_pred_best))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.97      0.95    117877
#            1       0.93      0.80      0.86     46927
#
#     accuracy                           0.92    164804
#    macro avg       0.92      0.89      0.90    164804
# weighted avg       0.92      0.92      0.92    164804

# %% [markdown]
# #### Training the XGBoost Model

# %%
xgb_model = XGBClassifier(use_label_encoder = False, eval_metric = 'logloss', random_state = 1234)
xgb_model.fit(X_train_smote, y_train_smote)

y_pred_xgb = xgb_model.predict(X_test_scaled)

print("Classification Report (XGBoost):")
print(classification_report(y_test, y_pred_xgb))

roc_auc = roc_auc_score(y_test, y_pred_xgb)
print(f"ROC AUC Score: {roc_auc}")
# Out:
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\xgboost\training.py:183: UserWarning: [23:35:56] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Classification Report (XGBoost):
#               precision    recall  f1-score   support
#
#            0       0.93      0.96      0.94    117877
#            1       0.89      0.82      0.85     46927
#
#     accuracy                           0.92    164804
#    macro avg       0.91      0.89      0.90    164804
# weighted avg       0.92      0.92      0.92    164804
#
# ROC AUC Score: 0.8880207885344922

# %% [markdown]
# #### Hyperparameter Tuning

# %%
xgb_model = XGBClassifier(random_state = 1234, use_label_encoder = False, eval_metric = 'logloss')

param_grid = {
    'n_estimators': [100, 300, 500],
    'max_depth': [3, 5, 7, 10],
    'learning_rate': [0.01, 0.1, 0.2],
    'subsample': [0.6, 0.8, 1.0],
    'colsample_bytree': [0.6, 0.8, 1.0],
    'gamma': [0, 1, 5],
}

cv = StratifiedKFold(n_splits = 3, shuffle = True, random_state = 1234)

xgb_random_search = RandomizedSearchCV(
    estimator = xgb_model,
    param_distributions = param_grid,
    n_iter = 25,
    scoring = 'f1_weighted',
    cv = cv,
    verbose = 2,
    random_state = 1234,
    n_jobs = -1
)

xgb_random_search.fit(X_train_scaled, y_train)

print("Best Parameters:", xgb_random_search.best_params_)
print("Best F1 Score (train):", xgb_random_search.best_score_)
# Out:
# Fitting 3 folds for each of 25 candidates, totalling 75 fits
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\xgboost\training.py:183: UserWarning: [23:38:07] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Best Parameters: {'subsample': 0.6, 'n_estimators': 500, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 1, 'colsample_bytree': 0.8}
# Best F1 Score (train): 0.9231166230172332

# %%
xgb_best = xgb_random_search.best_estimator_
y_pred = xgb_best.predict(X_test_scaled)

print(classification_report(y_test, y_pred))
print("ROC AUC Score:", roc_auc_score(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.98      0.95    117877
#            1       0.93      0.79      0.86     46927
#
#     accuracy                           0.92    164804
#    macro avg       0.93      0.89      0.90    164804
# weighted avg       0.93      0.92      0.92    164804
#
# ROC AUC Score: 0.8858162298747058

# %% [markdown]
# #### Threshold Tuning

# %%
y_proba_xgb = xgb_best.predict_proba(X_test_scaled)[:, 1]

thresholds = np.arange(0.1, 0.9, 0.05)
precision_scores = []
recall_scores = []
f1_scores = []

for thresh in thresholds:
    y_pred_thresh = (y_proba_xgb >= thresh).astype(int)
    precision_scores.append(precision_score(y_test, y_pred_thresh))
    recall_scores.append(recall_score(y_test, y_pred_thresh))
    f1_scores.append(f1_score(y_test, y_pred_thresh))

plt.figure(figsize = (10, 6))
plt.plot(thresholds, precision_scores, label = 'Precision', color = 'red')
plt.plot(thresholds, recall_scores, label = 'Recall', color = 'green')
plt.plot(thresholds, f1_scores, label = 'F1 Score', color = 'blue')
plt.axvline(x = 0.50, linestyle = '--', color = 'gray', label = 'Threshold (0.50)')
plt.title("Precision, Recall, F1 vs Threshold - XGBoost")
plt.xlabel("Threshold")
plt.ylabel("Score")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# #### Continuing With Random Forest
