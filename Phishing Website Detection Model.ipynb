# %% [markdown]
# ##### Author
#
# **Name**: Andres Figueroa
# **Email**: andresfigueroa@brandeis.edu
#
# ##### Project Description
#
# This project aims to build a machine learning classifier that can detect whether a given website URL is phishing (malicious) or legitimate (safe). By extracting and analyzing features from raw URLs.
#
# ---

# %% [markdown]
# #### Importing Libraries

# %%
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import SMOTE
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import make_scorer, recall_score, classification_report, confusion_matrix, roc_auc_score, precision_recall_curve, auc, roc_curve,precision_score, recall_score, f1_score
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.metrics import ConfusionMatrixDisplay, RocCurveDisplay, PrecisionRecallDisplay
from sklearn.model_selection import cross_val_score, StratifiedKFold, GridSearchCV, RandomizedSearchCV, train_test_split
from scipy.stats import randint, uniform
from collections import Counter
from urllib.parse import urlparse, parse_qs

# %% [markdown]
# ---
#
# ### Step 1: Loading and Exploring the Dataset

# %%
df = pd.read_csv('phishing_site_urls.csv')

print(df.columns)
print(df.head())
# Out:
# Index(['URL', 'Label'], dtype='object')
#                                                  URL Label
# 0  nobell.it/70ffb52d079109dca5664cce6f317373782/...   bad
# 1  www.dghjdgf.com/paypal.co.uk/cycgi-bin/webscrc...   bad
# 2  serviciosbys.com/paypal.cgi.bin.get-into.herf....   bad
# 3  mail.printakid.com/www.online.americanexpress....   bad
# 4  thewhiskeydregs.com/wp-content/themes/widescre...   bad

# %% [markdown]
# ---
#
# ### Step 2: Defining Our ML Problem
#
# ##### Dataset Explanation
#
# The dataset consists of raw website URLs along with labels indicating whether each URL is **phishing (bad)** or **legitimate (good)**. From these raw strings, we extract key features that represent characteristics often associated with phishing websites.
#
# The dataset includes:
#
# - Raw URL strings
# - Labels (`good` or `bad`)
#
# ---
#
# ##### 🎯 Prediction Target (Label)
#
# The label we are predicting is: `Label`
#
# This is a binary classification target:
#
# - `1` → The URL is 'bad' **(malicious)**
# - `0` → The URL is 'good' **(safe)**
#
# ---
#
# ##### Problem Type
#
# This is a supervised learning problem because we are training the model using examples with known outcomes (i.e., labeled URLs).
#
# - **Type**: Binary Classification
# - **Goal**: Predict whether a given website URL is phishing or not
#
# ---
#
# ##### Importance
#
# Phishing attacks are one of the most common cybersecurity threats, used to steal personal data, login credentials, or financial information. This project is important because:
#
# - It shows how machine learning can aid in automated phishing detection
# - It highlights the power of feature engineering for security-related tasks
# - It has practical use cases in browser security, email filtering, and endpoint protection tools
#
# ---

# %% [markdown]
# ### Step 3: Understanding Our Data

# %% [markdown]
# #### Missing Values

# %%
df.isnull().sum()
# Out:
# URL      0
# Label    0
# dtype: int64

# %% [markdown]
# > **Note:** No missing values, great!

# %%
df.dtypes
# Out:
# URL      object
# Label    object
# dtype: object

# %% [markdown]
# > **Note:** The `Label` column contains string values, so we need to convert it into a binary format for the model:
# > - **bad** → `1` (phishing)
# > - **good** → `0` (legitimate)

# %%
df['Label'].value_counts()
# Out:
# Label
# good    392924
# bad     156422
# Name: count, dtype: int64

# %% [markdown]
# > **Note:** There is a good amount of data, but there is also an imbalance between the two classifications.

# %% [markdown]
# #### Features to Engineer
# - `url_length`: Number of characters in the URL
# - `num_dots`: Number of `.` characters
# - `has_https`: `1` if the URL contains `'https'`, else `0`
# - `has_at`: `1` if the URL contains `'@'`, else `0`
# - `num_hyphens`: Number of `-` characters
# - `num_slashes`: Number of `/` characters
# - `has_ip_address`: `1` if the URL includes an IP address (e.g., `192.168.1.1`), else `0`
#
# > These patterns are commonly found in phishing URLs. Attackers use tricks like including IP addresses instead of domain names, adding many subdomains, or inserting symbols like @ to confuse users and hide the real destination of the link. These features help the model recognize suspicious URL structures.

# %% [markdown]
# #### URL `Length`

# %%
'''def get_url_length(url):
    return len(url)

df['url_length'] = df['URL'].apply(get_url_length)'''
# Out:
# "def get_url_length(url):\n    return len(url)\n\ndf['url_length'] = df['URL'].apply(get_url_length)"

# %% [markdown]
# > **Note:** Creates a column with the number of characters in a URL
#
# > `url_length`  was excluded from modeling because it had a high correlation with other features, making it redundant.

# %% [markdown]
# #### Number of Dots `.`

# %%
def count_dots(url):
    return url.count('.')

df['num_dots'] = df['URL'].apply(count_dots)

# %% [markdown]
# > **Note:** Creates a column that determines the number of `.` characters in a URL. Phishing URLs sometimes use extra dots to add subdomains or make the URL look more complex, which can help disguise the true destination.

# %% [markdown]
# #### Whether a URL has `HTTPS` or Not

# %%
'''def check_https(url):
    return 1 if 'https' in url.lower() else 0

df['has_https'] = df['URL'].apply(check_https)'''
# Out:
# "def check_https(url):\n    return 1 if 'https' in url.lower() else 0\n\ndf['has_https'] = df['URL'].apply(check_https)"

# %% [markdown]
# > **Note:** This feature creates a column that checks whether a URL uses HTTPS.
# > - `1` → URL **contains** `'https'` (secure)
# > - `0` → URL **does not contain** `'https'` (not secure)
#
# > Phishing URLs may avoid HTTPS, but many modern phishing sites now use HTTPS to appear legitimate, so it was removed from modeling.

# %% [markdown]
# #### Whether a URL has `@` or Not

# %%
'''def check_at_symbol(url):
    return 1 if '@' in url else 0

df['has_at'] = df['URL'].apply(check_at_symbol)'''
# Out:
# "def check_at_symbol(url):\n    return 1 if '@' in url else 0\n\ndf['has_at'] = df['URL'].apply(check_at_symbol)"

# %% [markdown]
# > **Note:** This feature creates a column that checks whether a URL uses @.
# > - `1` → URL **contains** `'@'`
# > - `0` → URL **does not contain** `'@'`
#
# > Phishing URLs sometimes use the `@` symbol to hide the real destination, as browsers may ignore everything before the `@`.
#
# > The feature was removed as there was little to no feature importance.

# %% [markdown]
# #### Number of Hyphens `-`

# %%
def count_hyphens(url):
    return url.count('-')

df['num_hyphens'] = df['URL'].apply(count_hyphens)

# %% [markdown]
# > **Note:** Creates a column that determines the number of `-` characters in a URL. Phishing URLs sometines use extra hyphens to create misleading or complex domain names, making the URL appear legitimate or to evade detection.

# %% [markdown]
# #### Number of Slashes `/`

# %%
'''def count_slashes(url):
    return url.count('/')

df['num_slashes'] = df['URL'].apply(count_slashes)'''
# Out:
# "def count_slashes(url):\n    return url.count('/')\n\ndf['num_slashes'] = df['URL'].apply(count_slashes)"

# %% [markdown]
# > **Note:** Creates a column that determines the number of `/` characters in a URL. Phishing URLs may use extra slashes to create long or complex paths, making the URL appear more legitimate or to hide the true destination.

# %% [markdown]
# #### Whether a URL has an `IP Address` or Not

# %%
'''ip_pattern = r'\b(?:\d{1,3}\.){3}\d{1,3}\b'

def check_ip_address(url):
    return 1 if re.search(ip_pattern, url) else 0

df['has_ip_address'] = df['URL'].apply(check_ip_address)'''
# Out:
# "ip_pattern = r'\x08(?:\\d{1,3}\\.){3}\\d{1,3}\x08'\n\ndef check_ip_address(url):\n    return 1 if re.search(ip_pattern, url) else 0\n\ndf['has_ip_address'] = df['URL'].apply(check_ip_address)"

# %% [markdown]
# > **Note:** This feature creates a column that checks whether a URL uses @.
# > - `1` → URL **contains** an IP Address
# > - `0` → URL **does not contain** an IP Address
#
# > The feature was removed as there was little to no feature importance.

# %% [markdown]
# #### Suspicious Words

# %%
'''def get_words(url):
    return re.findall(r'[a-zA-Z0-9]+', url.lower()) # finds all continuous sequences of letters and integers (a-z, upper, lower, 0-9).
    # "get_words" returns a list of words extracted from the URL

phishing_urls = df[df['Label'] == 1]['URL']
legit_urls = df[df['Label'] == 0]['URL']

# Counts the word frequency in 'phishing_urls'
phish_words = {}
for url in phishing_urls:
    for word in get_words(url): # Here, I am using 'get_words()' to extract the words from the URL and counting
        if word in phish_words:
            phish_words[word] += 1
        else:
            phish_words[word] = 1

# Same thing as above but with 'legit_urls'
legit_words = {}
for url in legit_urls:
    for word in get_words(url):
        if word in legit_words:
            legit_words[word] += 1
        else:
            legit_words[word] = 1

# How we are determining whether a word is suspicious or not
suspicious_words = set() # Here, I am using a set to not deal with duplicates
for word, count in phish_words.items():
    if count > 20 and count > 3 * legit_words.get(word, 0): # To capture more frequent words and comparing them to 'legit_words'
        suspicious_words.add(word)

def suspicious_count(url):
    count = 0
    for word in get_words(url):
        if word in suspicious_words:
            count += 1
    return count

df['suspicious_word_count'] = df['URL'].apply(suspicious_count)
print(suspicious_words)'''
# Out:
# 'def get_words(url):\n    return re.findall(r\'[a-zA-Z0-9]+\', url.lower()) # finds all continuous sequences of letters and integers (a-z, upper, lower, 0-9).\n    # "get_words" returns a list of words extracted from the URL\n\nphishing_urls = df[df[\'Label\'] == 1][\'URL\']\nlegit_urls = df[df[\'Label\'] == 0][\'URL\']\n\n# Counts the word frequency in \'phishing_urls\'\nphish_words = {}\nfor url in phishing_urls:\n    for word in get_words(url): # Here, I am using \'get_words()\' to extract the words from the URL and counting\n        if word in phish_words:\n            phish_words[word] += 1\n        else:\n            phish_words[word] = 1\n\n# Same thing as above but with \'legit_urls\'\nlegit_words = {}\nfor url in legit_urls:\n    for word in get_words(url):\n        if word in legit_words:\n            legit_words[word] += 1\n        else:\n            legit_words[word] = 1\n\n# How we are determining whether a word is suspicious or not\nsuspicious_words = set() # Here, I am
# ...

# %% [markdown]
# > **Note:** This identifies suspicious words. I previously didn't account for this feature. Seeing how our baseline (the logistic regression model) performed, I will continue to use and see how it affects the other models, the random forest and XGBoost.
#
# > This feature was leaking data and I will not be proceeding with the feature when training the model.

# %% [markdown]
# ---
# ### Additional Feature Engineering

# %% [markdown]
# #### Additional Features to Engineer:
# - `num_digits`: Number of digits in the URL
# - `num_words`: Number of words in the URL
# - `entropy`: Calculating the entropy or randomness of a URL
# - `hostname_length`: The length of the hostname in the URL (e.g., paypal-login-update-security.com)
# - `path_length`: The length of the path of the URL (everything after the domain and before ?)
# - `query_length`: The length of the query of the URL (after ?)
# - `special_char_count`: Counts how many special characters (like @, _, %, $, etc.) appear in each URL.
#
# #### Features to Remove:
# - `has_at`
# - `has_https`

# %% [markdown]
# #### Number of `Digits`

# %%
def count_digits(s):
        count = 0
        for c in s:
            if c.isdigit():
                count += 1
        return count

df["digit_count"] = df['URL'].apply(count_digits)

# %% [markdown]
# > **Note:** This counts the number of digits in a URL (0 - 9). Phishing URLs sometimes include more digits to mimic legitimate IDs, session tokens.

# %% [markdown]
# #### URL `Entropy`

# %%
def shannon_entropy(s):
        if len(s) == 0:
            return 0
        prob = []
        for c in set(s):
            prob.append(s.count(c) / len(s))
        entropy = 0
        for p in prob:
            entropy += -p * np.log2(p)
        return entropy

df["url_entropy"] = df['URL'].apply(shannon_entropy)

# %% [markdown]
# > **Note:** This creates a column that measures the uncertainty, or randomness of a URL. If entropy is low, the outocome is predictable. If entropy is high, the outocome is unpredictable.

# %% [markdown]
# #### URL `Word Count`

# %%
def word_count(url):
    separators = ['.', '/', '-', '_']
    for sep in separators:
        url = url.replace(sep, ' ')
    return len(url.split())

df['url_word_count'] = df['URL'].apply(word_count)

# %% [markdown]
# > **Note:** This creates a column that counts the number of words in a URL. Phishing URLs may use more segments or words to appear legitimate or to hide their true intent.

# %% [markdown]
# #### URL `Hostname Length`

# %%
'''def get_hostname_length(url):
    try:
        parsed = urlparse(url)
        if parsed.hostname:
            return len(parsed.hostname)
        else:
            return 0
    except:
        return 0

df['hostname_length'] = df['URL'].apply(get_hostname_length)'''
# Out:
# "def get_hostname_length(url):\n    try:\n        parsed = urlparse(url)\n        if parsed.hostname:\n            return len(parsed.hostname)\n        else:\n            return 0\n    except:\n        return 0\n\ndf['hostname_length'] = df['URL'].apply(get_hostname_length)"

# %% [markdown]
# > **Note:** The feature `hostname_length` was engineered to measure the length of the hostname portion of each URL.
#
# > `hostname_length` was excluded from modeling because it showed low feature importance in model interpretation.

# %% [markdown]
# #### URL `Path Length`

# %%
'''def get_path_length(url):
    try:
        parsed = urlparse(url)
        return len(parsed.path)
    except:
        return 0
    
df['path_length'] = df['URL'].apply(get_path_length)'''
# Out:
# "def get_path_length(url):\n    try:\n        parsed = urlparse(url)\n        return len(parsed.path)\n    except:\n        return 0\n    \ndf['path_length'] = df['URL'].apply(get_path_length)"

# %% [markdown]
# > **Note:** The feature `path_length` counts the number of characters in the path portion of a URL. This feature was included in modeling because it can help identify suspicious URLs which often use long or complex paths to hide their true intent.

# %% [markdown]
# #### URL `Query Length`

# %%
'''def get_query_length(url):
    try:
        parsed = urlparse(url)
        return len(parsed.query)
    except:
        return 0
    
df['query_length'] = df['URL'].apply(get_query_length)'''
# Out:
# "def get_query_length(url):\n    try:\n        parsed = urlparse(url)\n        return len(parsed.query)\n    except:\n        return 0\n    \ndf['query_length'] = df['URL'].apply(get_query_length)"

# %% [markdown]
# > **Note:** The feature `query_length` measures the number of characters in the query portion of a URL (everything after the `'?'`).
#
# > This feature was excluded from modeling because:
# > - It showed low feature importance during model interpretation.
# > - It had a high correlation with other length-based features, making it redundant.

# %% [markdown]
# #### Number of `Special Characters (like @, _, %, $, etc.)`

# %%
def special_char_count(url):
    specials = r'[@_\-=+%$&#?*!~]'
    return len(re.findall(specials, url))

df['special_char_count'] = df['URL'].apply(special_char_count)

# %% [markdown]
# > **Note:** The feature `query_length` measures the number of characters in the query portion of a URL (everything after the `'?'`).
#
# > This feature was excluded from modeling because:
# > - It showed low feature importance during model interpretation.
# > - It had a high correlation with other length-based features, making it redundant.

# %% [markdown]
# #### `Vowel Ratio`

# %%
def vowel_ratio(url):
    vowels = "aeiou"
    total = len(url)
    if total == 0:
        return 0
    vcount = sum(1 for c in url.lower() if c in vowels)
    return vcount / total

df['vowel_ratio'] = df['URL'].apply(vowel_ratio)

# %% [markdown]
# > **Note:** The feature `vowel_ratio` calculates the proportion of vowels (a, e, i, o, u) to total characters in a URL. This can help identify URLs with unusual character patterns, as phishing URLs sometimes use random or less natural text to evade detection.

# %% [markdown]
# #### `Consecutive Consonants`

# %%
def consecutive_consonants(url):
    return max((len(m.group()) for m in re.finditer(r'[^aeiou\W\d_]+', url.lower())), default=0)

df['consecutive_consonants'] = df['URL'].apply(consecutive_consonants)

# %% [markdown]
# > **Note:** The feature `consecutive_consonants` measures the longest sequence of consecutive consonant letters in a URL. Phishing URLs often use unnatural or random strings to evade detection, which can result in long runs of consonants.

# %% [markdown]
# #### Number of `Subdomains`

# %%
'''def subdomain_count(url):
    hostname = urlparse(url).hostname
    if hostname is None:
        return 0
    return max(0, hostname.count('.') - 1)

df['subdomain_count'] = df['URL'].apply(subdomain_count)'''
# Out:
# "def subdomain_count(url):\n    hostname = urlparse(url).hostname\n    if hostname is None:\n        return 0\n    return max(0, hostname.count('.') - 1)\n\ndf['subdomain_count'] = df['URL'].apply(subdomain_count)"

# %% [markdown]
# > **Note:** The feature `subdomain_count` measures how many subdomains are present in the hostname of a URL (for example, 'login.paypal.security.com' has two subdomains: 'login' and 'paypal').
#
# > This feature was excluded from modeling because:
# > - It showed low feature importance during model interpretation.
# > - It was often redundant with other structural features

# %% [markdown]
# #### Number of `Repeated Characters`

# %%
'''def repeated_char_count(url):
    return sum(len(m.group()) - 1 for m in re.finditer(r'(.)\1+', url))

df['repeated_char_count'] = df['URL'].apply(repeated_char_count)'''
# Out:
# "def repeated_char_count(url):\n    return sum(len(m.group()) - 1 for m in re.finditer(r'(.)\x01+', url))\n\ndf['repeated_char_count'] = df['URL'].apply(repeated_char_count)"

# %% [markdown]
# > **Note:** The feature `repeated_char_count` counts the total number of characters in a URL that appear in consecutive repeated runs (For example, 'aa', 'bbb'). Phishing URLs often use repeated characters to create confusing or misleading links.

# %% [markdown]
# #### Ratio of `Upper to Lower Case Characters`

# %%
def uppercase_ratio(url):
    uppers = sum(c.isupper() for c in url)
    return uppers / len(url) if len(url) > 0 else 0

df['uppercase_ratio'] = df['URL'].apply(uppercase_ratio)

# %% [markdown]
# > **Note:** The feature `uppercase_ratio` calculates the proportion of uppercase letters to total characters in a URL. Phishing URLs sometimes use unusual capitalization patterns to evade detection or mimic legitimate brands.

# %% [markdown]
# #### Number of `Query Parameters`

# %%
'''def param_count(url):
    return len(parse_qs(urlparse(url).query))

df['param_count'] = df['URL'].apply(param_count)'''
# Out:
# "def param_count(url):\n    return len(parse_qs(urlparse(url).query))\n\ndf['param_count'] = df['URL'].apply(param_count)"

# %% [markdown]
# > **Note:** The feature `param_count` measures how many query parameters are present in the URL (e.g., `'?id=123&ref=abc'` has 2 parameters).Phishing URLs sometimes use multiple parameters to obfuscate their intent or deliver malicious payloads.
#
# > This feature was excluded from modeling because of the low feature importance and redundancy.

# %% [markdown]
# #### Ratio of `Alphanumeric Characters to Total Characters`

# %%
def alnum_ratio(url):
    return sum(c.isalnum() for c in url) / len(url) if len(url) > 0 else 0

df['alnum_ratio'] = df['URL'].apply(alnum_ratio)

# %% [markdown]
# > **Note:** The feature `alnum_ratio` calculates the proportion of alphanumeric characters (letters and digits) to the total number of characters in a URL. Phishing URLs may use more special symbols or non-alphanumeric characters to hide their intent.

# %% [markdown]
# #### Longest `Word Length`

# %%
def longest_word_length(url):
    words = re.findall(r"[A-Za-z]+", url)
    return max((len(word) for word in words), default=0)

df['longest_word_length'] = df['URL'].apply(longest_word_length)

# %% [markdown]
# > **Note:** The feature `longest_word_length` finds the length of the longest sequence of consecutive letters in a URL. Phishing URLs may contain long or random words to avoid detection.

# %% [markdown]
# #### Ratio of `Digits to Characters`

# %%
def digit_to_char_ratio(url):
    return sum(c.isdigit() for c in url) / len(url) if len(url) > 0 else 0

df['digit_to_char_ratio'] = df['URL'].apply(digit_to_char_ratio)

# %% [markdown]
# > **Note:** The feature `digit_to_char_ratio` calculates the proportion of digit characters (0-9) to the total number of characters in a URL. Phishing URLs may use more digits to mimic legitimate IDs or create confusion.

# %% [markdown]
# #### `Consecutive Digits`

# %%
def consecutive_digits(url):
    return max((len(run) for run in re.findall(r'\d+', url)), default=0)

df['consecutive_digits'] = df['URL'].apply(consecutive_digits)

# %% [markdown]
# > **Note:** The feature `consecutive_digits` measures the longest sequence of consecutive digit characters in a URL. Phishing URLs may use long runs of digits to mimic IDs, session tokens, or hide malicious intent.

# %% [markdown]
# #### `Character Diversity`

# %%
def char_diversity(url):
    return len(set(url)) / len(url) if len(url) > 0 else 0

df['char_diversity'] = df['URL'].apply(char_diversity)

# %% [markdown]
# > **Note:** The feature `char_diversity` calculates the ratio of unique characters to the total number of characters in a URL. Phishing URLs may use a wider variety of characters to appear complex or to evade detection.

# %% [markdown]
# #### Encoding `'Label'` Our Label

# %%
df['Label'] = df['Label'].map({'good': 0, 'bad': 1})

# %%
df.head()
# Out:
#                                                  URL  Label  num_dots  \
# 0  nobell.it/70ffb52d079109dca5664cce6f317373782/...      1         6
# 1  www.dghjdgf.com/paypal.co.uk/cycgi-bin/webscrc...      1         5
# 2  serviciosbys.com/paypal.cgi.bin.get-into.herf....      1         7
# 3  mail.printakid.com/www.online.americanexpress....      1         6
# 4  thewhiskeydregs.com/wp-content/themes/widescre...      1         1
#
#    num_hyphens  digit_count  url_entropy  url_word_count  special_char_count  \
# 0            4           58     5.026886              25                  16
# 1            2            1     4.686883              13                   6
# 2            1           47     4.721044              19                   1
# 3            0            0     4.079842               9                   0
# 4            1           21     4.608653              11                   2
#
#    vowel_ratio  consecutive_consonants  uppercase_ratio  alnum_ratio  \
# ...

# %%
df.dtypes
# Out:
# URL                        object
# Label                       int64
# num_dots                    int64
# num_hyphens                 int64
# digit_count                 int64
# url_entropy               float64
# url_word_count              int64
# special_char_count          int64
# vowel_ratio               float64
# consecutive_consonants      int64
# uppercase_ratio           float64
# alnum_ratio               float64
# longest_word_length         int64
# digit_to_char_ratio       float64
# consecutive_digits          int64
# char_diversity            float64
# dtype: object

# %% [markdown]
# #### Correlation Heatmap

# %%
df.drop(columns=['URL'], inplace=True)

corr = df.corr()
plt.figure(figsize=(12, 10))
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# > **Note:** This is a correlation matrix heatmap. A heatmap shows how strongly each pair of features in our dataset is related. Correlation values range from:
# > - +1: perfect positive correlation (both variables increase together).
# > - 0: no linear relationship.
#
# > Here, our features have weak-to-moderate linear relationships with the target. So, there's not much linearity, so I probably don’t need to remove any features due to redundancy.

# %% [markdown]
# ---
# ### Step 4: Defining Our Project Plan
#
# #### Feature Selection
# After analyzing the data and the correlation matrix, I decided to **keep all existing engineered features**, as none showed excessive multicollinearity or redundancy. My final feature list is:
# - `url_length`
# - `num_dots`
# - `num_hyphens`
# - `num_slashes`
# - `has_https`
# - `has_at`
# - `has_ip_address`
#
# These features capture structural and security-related patterns in URLs that can help distinguish between phishing and legitimate sites.
#
# ---
#
# #### Data Preparation
# To prepare the data for modeling, I:
# 1. **Checked for and handled missing values**: I will validate before modeling.
# 2. **Encoding the Label**
# 3. **Address the Class Imbalance with SMOTE**
#
# ---
#
# #### Model Selection
# I plan to experiment with several models to find the best performer:
# - **Logistic Regression**: A strong baseline for binary classification.
# - **Random Forest Classifier**: A tree-based ensemble model that can handle non-linear relationships and provide feature importance.
# - **XGBoost Classifier**: A powerful gradient-boosted tree model that excels on tabular data.
#
# ---
#
# #### Evaluation Strategy
# To assess model performance:
#   - Precision
#   - Recall
#   - F1 Score
#   - ROC AUC Score
#
# Our main focus is going to be high recall for Class 1 (`phishing detection`)
#
# ---

# %% [markdown]
# ### Step 5: Implementing Our Project Plan

# %%
y = df['Label']
X = df.drop(columns = 'Label')

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 1234, stratify = y)

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled  = scaler.transform(X_test)

# %%
smote = SMOTE(random_state = 1234)
X_train_smote, y_train_smote = smote.fit_resample(X_train_scaled, y_train)

'''unique_smote, counts_smote = np.unique(y_train_smote, return_counts = True)
print("\nSMOTE class distribution:")
for label, count in zip(unique_smote, counts_smote):
    print(f"Label {label}: {count} samples")'''
# Out:
# 'unique_smote, counts_smote = np.unique(y_train_smote, return_counts = True)\nprint("\nSMOTE class distribution:")\nfor label, count in zip(unique_smote, counts_smote):\n    print(f"Label {label}: {count} samples")'

# %% [markdown]
# #### Training the Logistic Regression Model

# %%
lr = LogisticRegression(max_iter = 1000)
lr.fit(X_train_smote, y_train_smote)
y_pred = lr.predict(X_test_scaled)
y_proba = lr.predict_proba(X_test_scaled)[:, 1]

print(classification_report(y_test, y_pred))
print("ROC AUC:", roc_auc_score(y_test, y_proba))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.74      0.79    117877
#            1       0.51      0.68      0.58     46927
#
#     accuracy                           0.72    164804
#    macro avg       0.68      0.71      0.69    164804
# weighted avg       0.76      0.72      0.73    164804
#
# ROC AUC: 0.7973534185039703

# %% [markdown]
# > **Note:** The model seems to favor “good” URLs (as it has higher precision/recall), but struggles to identify “bad” (phishing) URLs, which is the priority in phishing detection.

# %% [markdown]
# #### Training the Random Forest Model

# %%
rf_model = RandomForestClassifier(random_state = 1234)
rf_model.fit(X_train_smote, y_train_smote)
y_pred = rf_model.predict(X_test_scaled)
y_proba = rf_model.predict_proba(X_test_scaled)[:, 1]

print(classification_report(y_test, y_pred))
print("ROC AUC:", roc_auc_score(y_test, y_proba))
# print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.95      0.94    117877
#            1       0.87      0.84      0.85     46927
#
#     accuracy                           0.92    164804
#    macro avg       0.90      0.90      0.90    164804
# weighted avg       0.92      0.92      0.92    164804
#
# ROC AUC: 0.9657509375709821

# %% [markdown]
# > **Note:** This is the highest I could get it. What's really frusturating is that I am using so many features. More features, more hypertuning tuning, more time down the drain (around 360mins).

# %% [markdown]
# #### Hypertuning Parameters

# %%
param_dist = {
    "n_estimators": [200, 400, 600],          
    "max_depth": [10, 15, None],              
    "max_features": ["sqrt", "log2"],         
    "min_samples_split": [2, 5, 10],          
    "class_weight": [None, "balanced"]        
}

random_search = RandomizedSearchCV(
    estimator = RandomForestClassifier(random_state = 1234),
    param_distributions = param_dist,
    n_iter = 15, # previously 20
    cv = 3,
    verbose = 1,
    n_jobs = -1,
    scoring = 'f1'
)

random_search.fit(X_train_smote, y_train_smote)  
best_rf = random_search.best_estimator_
print("Best Parameters:", random_search.best_params_)
# Out:
# Fitting 3 folds for each of 15 candidates, totalling 45 fits
# Best Parameters: {'n_estimators': 600, 'min_samples_split': 2, 'max_features': 'log2', 'max_depth': None, 'class_weight': 'balanced'}

# %%
y_pred_rf = best_rf.predict(X_test_scaled)
y_proba_rf = best_rf.predict_proba(X_test_scaled)[:, 1]

print("Classification Report (Optimized Random Forest):")
print(classification_report(y_test, y_pred_rf))

roc_score = roc_auc_score(y_test, y_proba_rf)
print(f"ROC AUC Score: {roc_score}")
# Out:
# Classification Report (Optimized Random Forest):
#               precision    recall  f1-score   support
#
#            0       0.94      0.95      0.94    117877
#            1       0.87      0.84      0.86     46927
#
#     accuracy                           0.92    164804
#    macro avg       0.90      0.90      0.90    164804
# weighted avg       0.92      0.92      0.92    164804
#
# ROC AUC Score: 0.966628017844193

# %% [markdown]
# > **Note:** The Default and Optimized Random Forest Models basically have the same metrics. All that happened was a small increase in the ROC AUC Score.

# %% [markdown]
# #### Threshold Tuning

# %%
thresholds = np.arange(0.1, 0.9, 0.05)
precision_scores = []
recall_scores = []
f1_scores = []

for thresh in thresholds:
    y_pred_thresh = (y_proba_rf >= thresh).astype(int)
    precision_scores.append(precision_score(y_test, y_pred_thresh))
    recall_scores.append(recall_score(y_test, y_pred_thresh))
    f1_scores.append(f1_score(y_test, y_pred_thresh))

plt.figure(figsize=(10, 6))
plt.plot(thresholds, precision_scores, label = 'Precision', color = 'red')
plt.plot(thresholds, recall_scores, label = 'Recall', color = 'green')
plt.plot(thresholds, f1_scores, label = 'F1 Score', color = 'blue')
plt.axvline(x = 0.50, linestyle = '--', label = 'Threshold (0.50)')
plt.title("Precision, Recall, F1 vs Threshold")
plt.xlabel("Threshold")
plt.ylabel("Score")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# > **Note:** Threshold optimization of recall comes at a significant cost to precision. Less Precision means that there are more false positives, so it's more likely that we'll flag a legit URL as a phishing URL.

# %%
best_idx = np.argmax(f1_scores)
best_threshold = thresholds[best_idx]
best_f1 = f1_scores[best_idx]

print(f"Optimal Threshold for Highest F1 Score: {best_threshold}")
print(f"Highest F1 Score: {best_f1}")
print(f"Precision: {precision_scores[best_idx]}, Recall: {recall_scores[best_idx]}")
# Out:
# Optimal Threshold for Highest F1 Score: 0.5500000000000002
# Highest F1 Score: 0.8560160858504505
# Precision: 0.8941285681132514, Recall: 0.8210198819442964

# %%
y_pred_best = (y_proba_rf >= best_threshold).astype(int)
print(classification_report(y_test, y_pred_best))
print("ROC AUC Score:", roc_auc_score(y_test, y_pred_best))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.96      0.95    117877
#            1       0.89      0.82      0.86     46927
#
#     accuracy                           0.92    164804
#    macro avg       0.91      0.89      0.90    164804
# weighted avg       0.92      0.92      0.92    164804
#
# ROC AUC Score: 0.8911592618744446

# %% [markdown]
# #### Training the XGBoost Model

# %%
xgb_model = XGBClassifier(use_label_encoder = False, eval_metric = 'logloss', random_state = 1234)
xgb_model.fit(X_train_smote, y_train_smote)

y_pred_xgb = xgb_model.predict(X_test_scaled)

print("Classification Report (XGBoost):")
print(classification_report(y_test, y_pred_xgb))

roc_auc = roc_auc_score(y_test, y_pred_xgb)
print(f"ROC AUC Score: {roc_auc}")
# Out:
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\xgboost\training.py:183: UserWarning: [12:50:45] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Classification Report (XGBoost):
#               precision    recall  f1-score   support
#
#            0       0.91      0.91      0.91    117877
#            1       0.78      0.78      0.78     46927
#
#     accuracy                           0.87    164804
#    macro avg       0.85      0.85      0.85    164804
# weighted avg       0.87      0.87      0.87    164804
#
# ROC AUC Score: 0.8453954043527447

# %% [markdown]
# #### Hyperparameter Tuning

# %%
xgb_model = XGBClassifier(random_state = 1234, use_label_encoder = False, eval_metric = 'logloss')

param_grid = {
    "n_estimators": [200, 400, 600],          
    "max_depth": [3, 5, 7],                   
    "learning_rate": [0.05, 0.1],             
    "subsample": [0.8, 1.0],                  
    "colsample_bytree": [0.8, 1.0],           
    "scale_pos_weight": [1, 2]          
}

cv = StratifiedKFold(n_splits = 3, shuffle = True, random_state = 1234)

xgb_random_search = RandomizedSearchCV(
    estimator = xgb_model,
    param_distributions = param_grid,
    n_iter = 15, # Previously 25
    scoring = 'f1',
    cv = 3   , # previously StratifiedKFold 'cv'
    verbose = 1,
    random_state = 1234,
    n_jobs = -1
)

xgb_random_search.fit(X_train_scaled, y_train)

print("Best Parameters:", xgb_random_search.best_params_)
print("Best F1 Score (train):", xgb_random_search.best_score_)
# Out:
# Fitting 3 folds for each of 15 candidates, totalling 45 fits
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\xgboost\training.py:183: UserWarning: [12:52:39] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Best Parameters: {'subsample': 0.8, 'scale_pos_weight': 2, 'n_estimators': 400, 'max_depth': 7, 'learning_rate': 0.1, 'colsample_bytree': 0.8}
# Best F1 Score (train): 0.7991576080629682

# %%
xgb_best = xgb_random_search.best_estimator_
y_pred = xgb_best.predict(X_test_scaled)

print(classification_report(y_test, y_pred))
print("ROC AUC Score:", roc_auc_score(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.91      0.92    117877
#            1       0.78      0.82      0.80     46927
#
#     accuracy                           0.88    164804
#    macro avg       0.85      0.87      0.86    164804
# weighted avg       0.89      0.88      0.88    164804
#
# ROC AUC Score: 0.865723306919136

# %% [markdown]
# #### Threshold Tuning

# %%
y_proba_xgb = xgb_best.predict_proba(X_test_scaled)[:, 1]

thresholds = np.arange(0.1, 0.9, 0.05)
precision_scores = []
recall_scores = []
f1_scores = []

for thresh in thresholds:
    y_pred_thresh = (y_proba_xgb >= thresh).astype(int)
    precision_scores.append(precision_score(y_test, y_pred_thresh))
    recall_scores.append(recall_score(y_test, y_pred_thresh))
    f1_scores.append(f1_score(y_test, y_pred_thresh))

plt.figure(figsize = (10, 6))
plt.plot(thresholds, precision_scores, label = 'Precision', color = 'red')
plt.plot(thresholds, recall_scores, label = 'Recall', color = 'green')
plt.plot(thresholds, f1_scores, label = 'F1 Score', color = 'blue')
plt.axvline(x = 0.50, linestyle = '--', color = 'gray', label = 'Threshold (0.50)')
plt.title("Precision, Recall, F1 vs Threshold - XGBoost")
plt.xlabel("Threshold")
plt.ylabel("Score")
plt.legend()
plt.grid(True)
plt.show()

# %%
best_idx = np.argmax(f1_scores)
best_threshold = thresholds[best_idx]
best_f1 = f1_scores[best_idx]

print(f"Optimal Threshold for Highest F1 Score: {best_threshold}")
print(f"Highest F1 Score: {best_f1}")
print(f"Precision: {precision_scores[best_idx]}, Recall: {recall_scores[best_idx]}")
# Out:
# Optimal Threshold for Highest F1 Score: 0.5500000000000002
# Highest F1 Score: 0.8024195718391114
# Precision: 0.8106650428428516, Recall: 0.7943401453321116

# %%
y_pred_best = (y_proba_xgb >= best_threshold).astype(int)
print(classification_report(y_test, y_pred_best))
print("ROC AUC Score (threshold-tuned):", roc_auc_score(y_test, y_pred_best))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.93      0.92    117877
#            1       0.81      0.79      0.80     46927
#
#     accuracy                           0.89    164804
#    macro avg       0.86      0.86      0.86    164804
# weighted avg       0.89      0.89      0.89    164804
#
# ROC AUC Score (threshold-tuned): 0.8602417490745154

# %% [markdown]
# > **Note:** XGBoost Performed the best after deleting the features that addressed @s and https

# %% [markdown]
# #### Continuing With Random Forest Feature Importance

# %%
importances = rf_model.feature_importances_
indices = np.argsort(importances)[::-1]

n_features = min(20, len(importances))

plt.figure(figsize=(10, 6))
plt.bar(range(n_features), importances[indices[:n_features]], align = "center")
plt.xticks(range(n_features), [X_train.columns[i] for i in indices[:n_features]], rotation = 90)
plt.title("Random Forest Feature Importance")
plt.show()

# %% [markdown]
# > **Note:** suspicious_word_count looks suspicious. This tell me that the model is relying heavily on the feature suspicious_word_count. This may be an indicator of data leakage. I am not a big fan of this as attackers can adapt their words to avoid detection.
#
# > After doing some research, I think has_at and has_https rank low because most modern phishing sites uses https and stopped using @s (it was supposedly a early 2000s problem).
#
# > It is probably best to exclude suspicious words.
#
# > hostname_length appears to contribute nothing to the model, so it will be removed for now, along with param_count, has_ip_address, maybe query_length.
